# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
obj = Series([4,7,-1,3])

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -1
# 3    3
# dtype: int64

# %%
obj.values #checking values of the Serie
# Out:
# array([ 4,  7, -1,  3], dtype=int64)

# %%
obj.index #checking indexes
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4,7,-5,3], index=['d','b','a','c']) #setting indexes by ourselvs

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['a']
# Out:
# -5

# %%
obj2['d'] = 6

# %%
obj2[['a','b','d']]
# Out:
# a   -5
# b    7
# d    6
# dtype: int64

# %%
#Mathematical operations don't effect on index-values relationship

# %%
obj2[obj2>0]
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
obj2 * 2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
#Dictionaries can be converted into Series

# %%
sdata = {'Ohio':35000,'Texas':71000,'Oregon':16000,'Utah':5000}
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ['California','Ohio','Oregon','Texas']
obj4 = pd.Series(sdata,index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
#Both the Series object itself and its index have a name attribute

# %%
obj4.name = 'population'

# %%
obj4.index.name = 'state'

# %%
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj
# Out:
# 0    4
# 1    7
# 2   -1
# 3    3
# dtype: int64

# %%
obj.index = ['Bob','Steve','Jeff','Ryan']

# %%
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -1
# Ryan     3
# dtype: int64

# %%
#DataFrame

# %%
data = {'state' : ['Ohio','Ohio','Ohio','Nevada','Nevada','Nevada'],
       'year' : [2000,2001,2002,2001,2002,2003],
       'pop' : [1.5,1.7,3.6,2.4,2.9,3.2]}

frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head() #first 5 rows
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
pd.DataFrame(data,columns=['year','state','pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
#If you pass a column that isn’t contained in the dict, it will appear with missing values in the result

frame2 = pd.DataFrame(data,columns=['year','state','pop','debt'],
                      index=['one','two','three','four',
                             'five','six'])

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
val = pd.Series([-1.2,-1.5,-1.7],index=['two','four','five'])
frame2['debt'] = val

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
frame2['eastern'] = frame2.state == 'Ohio' #adding a new column that don't exsist yet

# %%
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
del frame2['eastern'] #deleing a column

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
pop = {'Nevada' : {2001: 2.4, 2002 : 2.9},
      'Ohio': {2000: 1.5 , 2001 : 1.7 ,2002 : 1.6}}
frame3 = pd.DataFrame(pop)

# %%
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   1.6
# 2000     NaN   1.5

# %%
frame3.T
# Out:
#         2001  2002  2000
# Nevada   2.4   2.9   NaN
# Ohio     1.7   1.6   1.5

# %%
frame3.values
# Out:
# array([[2.4, 1.7],
#        [2.9, 1.6],
#        [nan, 1.5]])

# %%
#Index Objects

# %%
obj = pd.Series(range(3), index=['a','b','c'])
index = obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   1.6
# 2000     NaN   1.5

# %%
frame3.columns
# Out:
# Index(['Nevada', 'Ohio'], dtype='object')

# %%
'Ohio' in frame3.columns
# Out:
# True

# %%
2003 in frame3.index
# Out:
# False

# %%
obj = pd.Series([1,2,3,4],index=['a','b','c','d']) #Settting indexes
obj
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
obj2 = obj.reindex(['a','b','c','d','e'])

# %%
obj2 #Reindexed version
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    NaN
# dtype: float64

# %%
obj['b':'c']
# Out:
# b    2
# c    3
# dtype: int64

# %%
#Arithmetic and Data Alignment

# %%
s1 = pd.Series([7.3,-2.5,3.4,1.5], index=['a','c','d','e'])
s2 = pd.Series([-2.1,3.6,-1.5,4,3.1], index=['a','c','e','f','g'])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
#Summarizing and Computing Descriptive Statistics

# %%
import numpy as np 

df = pd.DataFrame([[1.4,np.nan],[7.1,-4.5],
                   [np.nan,np.nan],[0.75,-1.3]],
                  index=['a','b','c','d'],
                  columns=['one','two'])

# %%
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis='columns')
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean()
# Out:
# one    3.083333
# two   -2.900000
# dtype: float64

# %%
df.mean(axis='columns',skipna=False) #Mean without NaN values
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
df.idxmax() #Max value per index
# Out:
# one    b
# two    d
# dtype: object

# %%
df.idxmin() #Minimum value per index
# Out:
# one    d
# two    b
# dtype: object

# %%
df.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000
