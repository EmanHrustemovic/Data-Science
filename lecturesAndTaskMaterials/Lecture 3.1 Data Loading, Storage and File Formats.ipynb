# %%
import numpy as np
import pandas as pd

# %%
from pandas import DataFrame, Series

# %%
df = pd.read_csv('examples/ex1.csv') #loading whole dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('examples/ex1.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
# ...

# %%
pd.read_table('examples/ex1.csv',sep = ',') #to read table
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.read_table('examples/ex1.csv',sep = ',')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1282, in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1269 kwds_defaults = _refine_defaults_read(
#    1270     dialect,
# ...

# %%
list(open('examples/ex3.txt'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 list(open('examples/ex3.txt'))
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples/ex3.txt'

# %%
pd.options.display.max_rows = 10 # limiting on 10 rows

# %%
data.to_csv('examples/out.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.to_csv('examples/out.csv')
#
# NameError: name 'data' is not defined

# %%
# !cat examples/out.csv
,something,a,b,c,d,message
0,one,1,2,3.0,4,
1,two,5,6,,8,world,
2,three,9,10,11.0,12,foo
# Out:
#   Cell In[9], line 4
#     1,two,5,6,,8,world,
#               ^
# SyntaxError: invalid syntax

# %%
import sys

data.to_csv(sys.stdout, sep='I')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import sys
# ----> 3 data.to_csv(sys.stdout, sep='I')
#
# NameError: name 'data' is not defined

# %%
import csv

f = open('Kuki.csv')

reader = csv.reader(f)

for line in reader :
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 import csv
# ----> 3 f = open('Kuki.csv')
#       5 reader = csv.reader(f)
#       7 for line in reader :
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Kuki.csv'

# %%
with open('examples/ex7.csv') as f : 
    lines = list(csv.reader(f))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 with open('examples/ex7.csv') as f :
#       2     lines = list(csv.reader(f))
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples/ex7.csv'

# %%
header, values =  lines[0] , lines[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 header, values =  lines[0] , lines[1:]
#
# NameError: name 'lines' is not defined

# %%
data_dict = {h: v for h, v in zip(header,zip(*values))} # transposing rows and columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data_dict = {h: v for h, v in zip(header,zip(*values))}
#
# NameError: name 'header' is not defined

# %%
import json

# %%
result = json.loads(obj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 result = json.loads(obj)
#
# NameError: name 'obj' is not defined

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
pip install html5lib
# Out:
# ...
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/112.2 kB ? eta -:--:--
#    ---------- ---------------------------- 30.7/112.2 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------- --- 102.4/112.2 kB 980.4 kB/s eta 0:00:01
#    -------------------------------------- 112.2/112.2 kB 926.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
tables = pd.read_html('examples/fdic_failed_bank_list.html')
# Out:
# C:\Users\win11\AppData\Local\Temp\ipykernel_6432\1510043141.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html('examples/fdic_failed_bank_list.html')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 tables = pd.read_html('examples/fdic_failed_bank_list.html')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\html.py:1245, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1229 if isinstance(io, str) and not any(
#    1230     [
#    1231         is_file_like(io),
#    (...)
#    1235     ]
#    1236 ):
#    1237     warnings.warn(
# ...

# %%
len(tables)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 len(tables)
#
# NameError: name 'tables' is not defined

# %%
from bs4 import BeautifulSoup
import requests

url = ("https://raw.gihutbusercontent.com/"
      "joelgrus/data/master/getting-data.html")

html = requests.get(url).text
soup = BeautifulSoup(html,'html5lib')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...
